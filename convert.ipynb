# %% [markdown]
# # Converting
# Converting .xls data type into .csv for accessibility

# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('data.xls')
df.head()
# Out:
#    KEY  VAR_TARGET  VAR_1 VAR_2  VAR_3    VAR_4    VAR_5  VAR_6    VAR_7  \
# 0    1           0   6603     W   34.0      NaN      NaN    0.0      0.0
# 1    2           1   5210     I   34.0      NaN      NaN    0.0      0.0
# 2    3           1   2505     Q    7.0      NaN      NaN    0.0   1000.0
# 3    4           1   3902     Q   34.0      NaN      NaN    0.0   1000.0
# 4    5           1   4607     Q   34.0  11187.0  11187.0    1.0  27187.0
#
#     VAR_8  ...  VAR_41  VAR_42  VAR_43   VAR_44   VAR_45  VAR_46  VAR_47  \
# 0     0.0  ...     0.0     0.0     NaN      0.0      NaN     NaN     0.0
# 1     0.0  ...     0.0     0.0     NaN      0.0      0.0     NaN     0.0
# 2   915.0  ...   269.0  1004.0     NaN   1000.0   1000.0  1560.0   553.0
# 3   722.0  ...    30.0    16.0     NaN   1000.0   1000.0  1301.0    17.0
# 4  5436.0  ...    74.0    38.0     NaN  13594.0  16000.0  1518.0    19.0
#
#    VAR_48  VAR_49  VAR_50
# 0     NaN    1300     NaN
# 1     NaN    1570  1800.0
# ...

# %%
# Write DataFrame to CSV file
df.to_csv('data.csv', index=False)

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    KEY  VAR_TARGET  VAR_1 VAR_2  VAR_3    VAR_4    VAR_5  VAR_6    VAR_7  \
# 0    1           0   6603     W   34.0      NaN      NaN    0.0      0.0
# 1    2           1   5210     I   34.0      NaN      NaN    0.0      0.0
# 2    3           1   2505     Q    7.0      NaN      NaN    0.0   1000.0
# 3    4           1   3902     Q   34.0      NaN      NaN    0.0   1000.0
# 4    5           1   4607     Q   34.0  11187.0  11187.0    1.0  27187.0
#
#     VAR_8  ...  VAR_41  VAR_42  VAR_43   VAR_44   VAR_45  VAR_46  VAR_47  \
# 0     0.0  ...     0.0     0.0     NaN      0.0      NaN     NaN     0.0
# 1     0.0  ...     0.0     0.0     NaN      0.0      0.0     NaN     0.0
# 2   915.0  ...   269.0  1004.0     NaN   1000.0   1000.0  1560.0   553.0
# 3   722.0  ...    30.0    16.0     NaN   1000.0   1000.0  1301.0    17.0
# 4  5436.0  ...    74.0    38.0     NaN  13594.0  16000.0  1518.0    19.0
#
#    VAR_48  VAR_49  VAR_50
# 0     NaN    1300     NaN
# 1     NaN    1570  1800.0
# ...
